# %%
print("hello");
# Out:
# hello

# %%
a =976

# %%
type(a)
# Out:
# int

# %%
a =976.54 +4j
type(a)
# Out:
# complex

# %%
a='h'
type(a)
# Out:
# str

# %%
x= 'ganapathi'
y='surya'
print(x+y)
# Out:
# ganapathisurya

# %%
x + y
# Out:
# 'ganapathisurya'

# %%
x='Ganapathi'
y=' Surya'
x +y
# Out:
# 'Ganapathi Surya'

# %%
print((x+" "+y).upper())
# Out:
# GANAPATHI  SURYA

# %%
b={1,2,3,1,45,73,45,6,2,4,5,4,2,9,90,}
b
# Out:
# {1, 2, 3, 4, 5, 6, 9, 45, 73, 90}

# %%
b={2:"surya",5:"mummy"}
b
# Out:
# {2: 'surya', 5: 'mummy'}

# %%
b[5]
# Out:
# 'mummy'

# %%
2**8
# Out:
# 256

# %%
x=98
y=9
z=x**2 +9**4j
score=(z/y**2)
score
# Out:
# (118.5579685235109+0.007331919348551994j)

# %%
type(score)
# Out:
# complex

# %%
print("bye")
# Out:
# bye

# %%
Raw_Housing_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-703114c6d2cf> in <module>()
# ----> 1 Raw_Housing_data
#
# NameError: name 'Raw_Housing_data' is not defined

# %%
data.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4b0a381c0a10> in <module>()
# ----> 1 data.isnull.sum()
#
# NameError: name 'data' is not defined

# %%
data=
